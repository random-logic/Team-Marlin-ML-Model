# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import mahalanobis

# %%
# Load preprocessed DataFrame from the pickle file
with open('df.pkl', 'rb') as f:
    df = pickle.load(f)

df.head()
# Out:
#   food_category  restaurant               item_name  \
# 0          Soup  Applebee's       French Onion Soup
# 1          Soup  Applebee's       Tomato Basil Soup
# 2          Soup  Applebee's   Chicken Tortilla Soup
# 3        Salads  Applebee's             House Salad
# 4        Salads  Applebee's  Oriental Chicken Salad
#
#                                     item_description  calories  total_fat  \
# 0                           French Onion Soup, Soups     370.0       22.0
# 1                           Tomato Basil Soup, Soups     220.0       12.0
# 2                       Chicken Tortilla Soup, Soups     280.0       15.0
# 3                           House Salad, Side Salads     130.0        7.0
# 4  Oriental Chicken Salad, 1 Breadstick, Salad Dr...    1560.0      103.0
#
#    saturated_fat  trans_fat  cholesterol  sodium  carbohydrates  \
# 0           12.0        0.0         55.0  1250.0           26.0
# 1            4.5        1.5         25.0  1270.0           22.0
# 2            4.0        0.0         35.0   930.0           26.0
# 3            2.5        0.0         10.0   230.0           14.0
# 4           17.0        1.0         65.0  1610.0          120.0
#
#    dietary_fiber  sugar  protein
# 0            2.0    9.0     16.0
# 1            2.0    9.0      5.0
# 2            2.0    3.0     11.0
# 3            2.0    4.0      6.0
# 4           12.0   44.0     40.0

# %% [markdown]
# # KNN Euclidean Metric
#
# This is good for getting as close as possible to specified targets. The downside is that it does not make reasonable tradeoffs. For example, it can replace say 20g protein for 20 more calories. That is a terrible tradeoff.

# %%
# Get x params
X = df.drop(['food_category', 'restaurant', 'item_name', 'item_description'], axis = 1)

k = 10 # init number of neighbors to find
# Cols are calories, total_fat, saturated_fat, trans_fat, cholestrol, sodium, carbs, dietary_fiber, sugar, protein
target = [500, 20, 5, 0, 100, 1000, 50, 10, 5, 25] # our target

model = NearestNeighbors(n_neighbors = k, metric = 'euclidean')
model.fit(X)

distances, indices = model.kneighbors(np.array(target).reshape(1, -1))
nearest_neighbors_indices = indices[0]
nearest_neighbors = df.iloc[nearest_neighbors_indices]
nearest_neighbors
# Out:
# /home/random01/anaconda3/envs/marlin/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
#                 food_category          restaurant  \
# 15554                 Entrees         O'Charley's
# 16222  Toppings & Ingredients  Outback Steakhouse
# 6981                  Entrees         Dairy Queen
# 22611                    Soup      Steak 'N Shake
# 7393                  Entrees             Denny's
# 23115              Sandwiches              Subway
# 15054              Sandwiches          McDonald's
# 2408                   Salads           Bojangles
# 25253              Sandwiches         Whataburger
# 5183                   Salads         Chick Fil A
#
#                                           item_name  \
# 15554                  Low Country Shrimp with Rice
# 16222            Add 4 Grilled Shrimp on the Barbie
# 6981                   Pancake Platter with Sausage
# 22611                             Chili Deluxe, Cup
# 7393                    Jr. Cheeseburger (add side)
# 23115                 Grilled Chicken on Plain Wrap
# 15054                                         McRib
# 2408                        Homestyle Tenders Salad
# 25253  #11 Grilled Chicken Sandwich with Mayonnaise
# 5183   Grilled Market Salad w/ Grilled Filet (Cold)
#
#                                         item_description  calories  total_fat  \
# 15554  Low Country Shrimp with Rice, Seafood Favorite...     520.0       31.0
# 16222     Add 4 Grilled Shrimp on the Barbie, Plus It Up     510.0       35.0
# 6981             Pancake Platter with Sausage, Breakfast     520.0       24.0
# 22611                           Chili Deluxe, Cup, Chili     500.0       28.0
# 7393          Jr. Cheeseburger (add side), Kids' Entrees     470.0       25.0
# 23115  Grilled Chicken on Plain Wrap, Make any Sandwi...     470.0       11.0
# 15054                                  McRib, Sandwiches     500.0       26.0
# 2408                    Homestyle Tenders Salad , Salads     480.0       26.0
# 25253  #11 Grilled Chicken Sandwich with Mayonnaise, ...     470.0       20.0
# 5183   Grilled Market Salad w/ Grilled Filet (Cold), ...     510.0       31.0
#
#        saturated_fat  trans_fat  cholesterol  sodium  carbohydrates  \
# 15554            8.0        0.5         95.0  1000.0           39.0
# 16222           12.0        0.0        110.0  1010.0           31.0
# 6981             8.0        0.0        100.0   980.0           60.0
# 22611           16.0        0.5         80.0   980.0           36.0
# 7393            12.0        1.5         95.0  1000.0           34.0
# 23115            2.0        0.0        100.0  1010.0           54.0
# 15054           10.0        0.0         70.0   980.0           44.0
# 2408            10.0        0.5         85.0  1020.0           32.0
# 25253            4.5        0.0         90.0   980.0           42.0
# 5183             6.0        0.0         80.0  1020.0           41.0
#
#        dietary_fiber  sugar  protein
# 15554            2.0    8.0     20.0
# 16222            3.0    6.0     19.0
# 6981             4.0   11.0     17.0
# 22611            7.0    2.0     29.0
# 7393             1.0    5.0     27.0
# 23115            3.0    5.0     42.0
# 15054            3.0   11.0     22.0
# 2408             2.0    3.0     30.0
# 25253            4.0    9.0     32.0
# 5183             5.0   26.0     28.0

# %% [markdown]
# # KNN Cosine Metric
# This is good for if the proportion of nutrients matters more than the actual values. The downside is that if they don't have anyone to share with to get the precise amount.

# %%
# Get x params
X = df.drop(['food_category', 'restaurant', 'item_name', 'item_description'], axis = 1)

k = 10 # init number of neighbors to find
# Cols are calories, total_fat, saturated_fat, trans_fat, cholestrol, sodium, carbs, dietary_fiber, sugar, protein
target = [500, 20, 5, 0, 100, 1000, 50, 10, 5, 25] # our target

model = NearestNeighbors(n_neighbors = k, metric = 'cosine')
model.fit(X)

distances, indices = model.kneighbors(np.array(target).reshape(1, -1))
nearest_neighbors_indices = indices[0]
nearest_neighbors = df.iloc[nearest_neighbors_indices]
nearest_neighbors
# Out:
# /home/random01/anaconda3/envs/marlin/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
#                 food_category                   restaurant  \
# 1979                  Entrees  BJ's Restaurant & Brewhouse
# 3842                  Entrees     Carrabba's Italian Grill
# 2297   Toppings & Ingredients                    Bob Evans
# 4993               Sandwiches                  Chick Fil A
# 8500                  Entrees                     Domino's
# 3805       Appetizers & Sides     Carrabba's Italian Grill
# 23522              Sandwiches                    Taco Bell
# 17116                  Salads                 Panera Bread
# 23340              Sandwiches                    Taco Bell
# 19322              Sandwiches                   Portillo's
#
#                                             item_name  \
# 1979          Italian Chicken Parmesan with Spaghetti
# 3842           Shrimp and Scallop Linguine Alla Vodka
# 2297                          Breaded Chicken Breasts
# 4993                         Grilled Chicken Sandwich
# 8500                          Chicken Carbonara, Dish
# 3805                                    Shrimp Scampi
# 23522  Hash Brown Toasted Breakfast Burrito - Sausage
# 17116          Asian Sesame with Chicken Salad - Half
# 23340                    Breakfast Crunchwrap - Steak
# 19322                        Broiled Chicken Sandwich
#
#                                         item_description  calories  total_fat  \
# 1979   Italian Chicken Parmesan with Spaghetti, Lunch...     900.0       37.0
# 3842       Shrimp and Scallop Linguine Alla Vodka, Pasta    1070.0       35.0
# 2297   Breaded Chicken Breasts, Rolls, Available In: ...     590.0       21.0
# 4993                   Grilled Chicken Sandwich, Entrees     380.0       12.0
# 8500   Chicken Carbonara, Dish, Penne Pasta, Sandwich...     690.0       34.0
# 3805                           Shrimp Scampi, Appetizers     990.0       51.0
# 23522  Hash Brown Toasted Breakfast Burrito - Sausage...     570.0       33.0
# 17116     Asian Sesame with Chicken Salad - Half, Salads     200.0       11.0
# 23340            Breakfast Crunchwrap - Steak, Breakfast     660.0       38.0
# 19322                  Broiled Chicken Sandwich, Chicken     400.0       17.0
#
#        saturated_fat  trans_fat  cholesterol  sodium  carbohydrates  \
# 1979            11.0        0.0        184.0  1811.0           87.0
# 3842            13.0        0.0        185.0  2130.0          120.0
# 2297             4.5        0.0        115.0  1210.0           59.0
# 4993             2.0        0.0         75.0   760.0           43.0
# 8500            19.0        0.5        120.0  1370.0           63.0
# 3805            19.0        0.0        180.0  2010.0           87.0
# 23522           11.0        0.0        125.0  1170.0           52.0
# 17116            1.5        0.0         35.0   400.0           15.0
# 23340           12.0        0.0        140.0  1360.0           53.0
# 19322            4.0        0.0         80.0   769.0           36.0
#
#        dietary_fiber  sugar  protein
# 1979             7.0   17.0     54.0
# 3842            10.0   11.0     49.0
# 2297             2.0    8.0     40.0
# 4993             3.0   11.0     28.0
# 8500             2.0    6.0     30.0
# 3805             3.0    5.0     32.0
# 23522            3.0    3.0     18.0
# 17116            3.0    4.0     13.0
# 23340            4.0    3.0     24.0
# 19322            1.0    8.0     26.0

# %% [markdown]
# # KNN Mahalanobis Distance

# %%
# Get x params
X = df.drop(['food_category', 'restaurant', 'item_name', 'item_description'], axis = 1)

k = 10 # init number of neighbors to find
# Cols are calories, total_fat, saturated_fat, trans_fat, cholestrol, sodium, carbs, dietary_fiber, sugar, protein
target = [1000, 20, 5, 0, 100, 1000, 50, 10, 5, 50] # our target

def mahalanobis_distance(x1, x2, cov_inv):
    return mahalanobis(x1, x2, cov_inv)

cov_matrix = np.cov(X, rowvar=False)  # Calculate covariance matrix
cov_inv = np.linalg.inv(cov_matrix)  # Invert covariance matrix

model = NearestNeighbors(n_neighbors = k, metric=mahalanobis_distance, metric_params={'cov_inv': cov_inv})
model.fit(X)

distances, indices = model.kneighbors(np.array(target).reshape(1, -1))
nearest_neighbors_indices = indices[0]
nearest_neighbors = df.iloc[nearest_neighbors_indices]
nearest_neighbors
# Out:
# /home/random01/anaconda3/envs/marlin/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(